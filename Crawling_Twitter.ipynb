# %% [markdown]
# <a href="https://colab.research.google.com/github/panjiram/Program-Tugas-Akhir/blob/main/Crawling_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tweepy

# %%
import tweepy # libarary untuk Twitter
import csv    # library untuk membuat file CSV
import urllib.request
import requests as r
import csv
import pandas as pd

# %%
# twitter API access
api_key  = '86JrDrPHwb2FDzQ4BEaE157NK'
api_key_secret = 'FXGTuKw2UF2fnpF7viltXPgd6U7BxgKHhmvJ3JAfGBvWd931ol'
access_token = '865771920-5rj7nkixC6zGp8WE2yeO17hq6bxiu6GCpDj1NP53'
access_token_secret = 'KiqZ9hXaNakVOoVOB0A13frhC0tdz4qaEhPRYdu0Bd107'

# %%
# Autentikasi API Twitter menggunakan Tweepy
auth = tweepy.OAuthHandler(api_key, api_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
message,favorite_count,retweet_count,created_at,user_name,followers_count = [],[],[],[],[],[]

for tweet in tweepy.Cursor(api.search, q="ptm", rpp=10000, count=20, result_type="recent", include_entities=True, lang="id").items(2000):
    message.append(tweet.text)
    favorite_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    created_at.append(tweet.created_at)
    user_name.append(tweet.user.name)
    followers_count.append(tweet.user.followers_count)
    
list_ = {'Message': message, 
         'Favorite Count' : favorite_count,
         'Retweet Count' :retweet_count,
         'Created At' : created_at,
         'Username' : user_name,
         'Followers' : followers_count}

df = pd.DataFrame(list_)
df.to_csv("ptm.csv") #nama file
df
# Out:
#                                                 Message  ...  Followers
# 0     Gmn ya, alhamdulillah sih paham kalo gua msh b...  ...        935
# 1     🔥 Tadi pas ptm ketemu anak baru, gemess banget...  ...      28986
# 2     MASHA ALLAH cakep banget 🙏🏻🙏🏻 btw ini emang bg...  ...        106
# 3     pls lah yaaa, baru aja mulai ptm https://t.co/...  ...        350
# 4     Nadiem: Pelaksanaan PTM 100 Persen Menyesuaika...  ...       1824
# ...                                                 ...  ...        ...
# 1995  ptm 100% berarti parkiran rame, ada upacara, a...  ...         24
# 1996  di sekolah saya, ptm nya ganjil genap kayak mo...  ...        270
# 1997  boleh kok ngeluh capek ptm capek ptm, tp janga...  ...         98
# 1998  @adhiMID Keprihatinan saya adalah ketidakwaspa...  ...      11493
# 1999        @jooilysm ohh masi ptm terbatas, semangatt🤩  ...       1018
#
# [2000 rows x 6 columns]
